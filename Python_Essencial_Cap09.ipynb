# %% [markdown]
# <a href="https://colab.research.google.com/github/costaalisson2301/AED01/blob/main/Python_Essencial_Cap09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Capítulo 9 - Python Essencial: Curso Rápido para Iniciantes e Profissionais**
#
# ---

# %% [markdown]
# ## Módulos ou Pacotes em Python

# %% [markdown]
# #### Usando o módulo math

# %%
import math

# Usando a função sqrt() do módulo math para calcular a raiz quadrada
numero = 16
raiz_quadrada = math.sqrt(numero)
print(f"A raiz quadrada de {numero} é {raiz_quadrada}")
# Out:
# A raiz quadrada de 16 é 4.0

# %% [markdown]
# #### Usando o Pacote numpy

# %%
import numpy as np

# Criando um array simples com numpy
array = np.array([1, 2, 3, 4, 5])
print("Array criado com numpy:", array)
# Out:
# Array criado com numpy: [1 2 3 4 5]

# %% [markdown]
# #### Importando funções específicas

# %%
from math import pi, sin

# Usando as funções pi e sin diretamente
print(f"O valor de pi é {pi}")
print(f"O seno de 90 graus (em radianos) é {sin(pi/2)}")
# Out:
# O valor de pi é 3.141592653589793
# O seno de 90 graus (em radianos) é 1.0

# %% [markdown]
# #### Instalação de um pacote e sua utilização (matplotlib)

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# Dados para o gráfico
meses = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
vendas = [150, 200, 250, 300, 350, 400]

# Criando o gráfico de linha
plt.plot(meses, vendas)
plt.title('Vendas nos Primeiros Seis Meses')
plt.xlabel('Meses')
plt.ylabel('Vendas (em unidades)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### FIM
