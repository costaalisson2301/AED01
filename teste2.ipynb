# %% [markdown]
# <a href="https://colab.research.google.com/github/costaalisson2301/AED01/blob/main/teste2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite sua idade:"))
valor = int(input("digite um valor:"))

if idade > 16 and valor > 35.00:
  print("entrada permitida")

elif valor < 35:
  print("valor insuficiente")

elif idade < 16:
  print("idade insuficiente")
# Out:
# Digite sua idade:21
# digite um valor:44
# entrada permitida
