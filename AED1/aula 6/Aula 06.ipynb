# %%
idade = int(input("qual a sua idade "))
carro = (input("tem carro? <S?N>"))
if idade >= 18:
         if carro == "S":

            print("pode dirigir")
else:
    print("chamao uber")
# Out:
# qual a sua idade  42
# tem carro? <S?N> s

# %%
nota1 = int(input("digite sua nota"))
nota2 = int(input("digite sua nota"))
media = (nota1 + nota2) / 2
if media >= 5:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# digite sua nota 6
# digite sua nota 5
# Aprovado

# %%
nota1 = int(input("digite sua nota"))
if nota1 >=7:
    nota1 = nota1+ 0.5        
nota2 = int(input("digite sua nota"))
if nota2 >=7:
    nota2 = nota2+ 0,5
media = (nota1+nota2) / 2
if media >= 5:
    print("Aprovado")
else:
    print("Reprovado")
    7
# Out:
# digite sua nota 8
# digite sua nota 6
# Aprovado

# %%
lado1 = float(input("Digite o primeiro lado:"))
lado2 = float(input("Digite o segundo lado:"))
lado3 = float(input("Digite o tercerio lado:"))
if (lado1 + lado2 > lado3) and (lado1 + lado3 > lado2) and (lado2 + lado3 > lado1):
    print("Os valores formam um triangulo!")
if lado1 == lado1 ==lado2 == lado3:
    print("Tipo:Equilatero (três lados iguais )")
elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
    print("Tipo: Isósceles (dois lados iguais)")
else:
    print("Os valores NÃO podem formar um triangulo.")
# Out:
# Digite o primeiro lado: 1
# Digite o segundo lado: 2
# Digite o tercerio lado: 3
# Os valores NÃO podem formar um triangulo.
