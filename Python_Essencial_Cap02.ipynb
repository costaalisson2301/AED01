# %% [markdown]
# <a href="https://colab.research.google.com/github/costaalisson2301/AED01/blob/main/Python_Essencial_Cap02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Capítulos 2 - Python Essencial: Curso Rápido para Iniciantes e Profissionais**
#
# ---

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Dilermando Piva Jr.")
# Out:
# Dilermando Piva Jr.

# %% [markdown]
# **FIM**
