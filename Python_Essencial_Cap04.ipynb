# %% [markdown]
# <a href="https://colab.research.google.com/github/costaalisson2301/AED01/blob/main/Python_Essencial_Cap04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Capítulo 4 - Python Essencial: Curso Rápido para Iniciantes e Profissionais**
#
# ---

# %% [markdown]
# **Operadores Aritméticos**

# %%
4 + 8
# Out:
# 12

# %%
num1 = 34
num2 = 66
(num1 + num2)
# Out:
# 100

# %%
num1 = 45
num2 = 25
56 - 34
# Out:
# 22

# %%
56 + 34 - 29
# Out:
# 61

# %%
(num1 - num2)
# Out:
# 20

# %%
num1 = 467
num2 = 345
262 * 3
# Out:
# 786

# %%
45 * 3 + 35 - 23
# Out:
# 147

# %%
(num1 * num2)
# Out:
# 161115

# %%
100 / 4
# Out:
# 25.0

# %%
100 / 11
# Out:
# 9.090909090909092

# %%
num1 = 78
num2 = 8
print(num1 / num2)
# Out:
# 9.75

# %%
print(num1 // num2)
# Out:
# 9

# %%
9 % 3
# Out:
# 0

# %%
45 % 20
# Out:
# 5

# %%
3**2
# Out:
# 9

# %%
65**12
# Out:
# 5688009063105712890625

# %%
num = 89
power = 6
print(num**power)
# Out:
# 496981290961

# %% [markdown]
# **Operadores Aritméticos**

# %%
45 == 45
# Out:
# True

# %%
x1 = 56 == 90
x2 = "piva" == "piva"
x3 = "diler" == 'DILER'
print("x1 = ", x1)
print("x2 = ", x2)
print("x3 = ", x3)
# Out:
# x1 =  False
# x2 =  True
# x3 =  False

# %%
x1 = 34 != 35
x2 = 765 != 765
x3 = 'PYTHON' != 'python'
print("x1 = ", x1)
print("x2 = ", x2)
print("x3 = ", x3)
# Out:
# x1 =  True
# x2 =  False
# x3 =  True

# %%
21 < 56
# Out:
# True

# %%
num1 = 66
num2 = 99
print(num1 < num2)
# Out:
# True

# %%
97 > 89
# Out:
# True

# %%
num1 = 456
num2 = 329
print(num1 >num2)
# Out:
# True

# %%
67 <= 85
# Out:
# True

# %%
100 >= 99
# Out:
# True

# %% [markdown]
# **Operadores de Atribuição**

# %%
x = 7
print(x)
x += 3
print(x)
# Out:
# 7
# 10

# %% [markdown]
# **Operadores Lógicos**

# %%
x = 92
(x < 100) and (x > 90)
# Out:
# True

# %%
x = 89
(x < 100) and (x > 90)
# Out:
# False

# %%
x = 89
(x < 100) or (x > 90)
# Out:
# True

# %%
x = 89
print(not (x < 100 or x > 90))
print(not (x < 100 and x > 90))
print(not (x < 100 and x > 90))
# Out:
# False
# True
# True

# %% [markdown]
# **Operadores de Identidade**

# %%
a = 9000
b = 9000
c = a
print(id(a))
print(id(b))
print(id(c))
# Out:
# 140583072178768
# 140583072177264
# 140583072178768

# %%
print(a is b)
print(a is c)
print(b is c)
# Out:
# False
# True
# False

# %%
a = 9
b = 9
c = a
print(id(a))
print(id(b))
print(id(c))
# Out:
# 140583368688112
# 140583368688112
# 140583368688112

# %% [markdown]
# **Operadores de Associação**

# %%
'a' in 'piva'
# Out:
# True

# %%
"r" in "piva"
# Out:
# False

# %%
"r" not in "piva"
# Out:
# True

# %% [markdown]
# **FIM**
