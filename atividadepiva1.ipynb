# %% [markdown]
# <a href="https://colab.research.google.com/github/costaalisson2301/AED01/blob/main/atividadepiva1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero1 = 28
numero2 = 54
print(numero1 *numero2)
# Out:
# 1512

# %%
 numero1 = int(input("Digite um número"))
 numero2 = int(input("Digite outro numero"))
 print(numero1 / numero2)
# Out:
# Digite um número12
# Digite outro numero4
# 3.0

# %%
numero = int(input("Digite um número: "))

if numero < 6:
    print("menor que o necessário")
elif numero > 6:
    print("bom, parabéns")
else:
    print("exatamente 6")
# Out:
# Digite um número: 8
# bom, parabéns

# %%
for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
x = range(15, 30)
x = list(x)

for w in x[3:8]:
    print(w)
# Out:
# 18
# 19
# 20
# 21
# 22

# %%
list [1,2,3]
# Out:
# list[1, 2, 3]

# %%
def e(b):
  a = 10
  e(a)
  return a
a = 10
e (a)
e(a)
print(e(a))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipykernel_5980/748326747.py in <cell line: 0>()
#       4   return a
#       5 a = 10
# ----> 6 e (a)
#       7 e(a)
#       8 print(e(a))
#
# /tmp/ipykernel_5980/748326747.py in e(b)
#       1 def e(b):
#       2   a = 10
# ----> 3   e(a)
#       4   return a
#       5 a = 10
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipykernel_5980/748326747.py in e(b)
#       1 def e(b):
#       2   a = 10
# ----> 3   e(a)
#       4   return a
#       5 a = 10
#
# RecursionError: maximum recursion depth exceeded
